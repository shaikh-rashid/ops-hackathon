# %% [markdown]
# # A gentle introduction to Python, File IO, Parallel Programming

# %% [markdown]
# ## What is Python?
#
# ![Image of Python](https://www.andreabacciu.com/upload/2015/02/Python-Logo-PNG-Image.png)

# %% [markdown]
# Python is a high level programming language created by Guido van Rossum in 1991.
#
# It is a popular language because it is easy to read, write, and understand. Python abstracts a lot of underlying computational details allowing the programmer to focus on the overall idea of what the program should do.
#
# Python is used extensively in data analytics and machine learning due to the the massive number of libraries supporting these endeavors.

# %% [markdown]
# ## Lesson 1 - Basic Programming & Python Syntax

# %% [markdown]
# I did tell you that Python is easy to read right? Lets put that to the test - what do you think this line of code does?
#
# (Select the code snippet by clicking on it with your mouse and then hit "Run" on the menu above.)

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# There are 2 things happening here:
#
#     1) A function called "print" is called.
#     2) The function is supplied with input data, that is, the text in quotations: "Hello World!"
#
# As a result, Hello World! is printed on to the screen. Go figure.

# %% [markdown]
# ### Variables
#
# In the previous coding example, you saw that a "function" could be supplied with data to produce a result. This "data" is more commonly refered to as "variables" in programming.
#
# The code snippet above could easily be re-written as:

# %%
greeting = "Hello World!"

print(greeting)
# Out:
# Hello World!

# %% [markdown]
# So what is the difference? In this scenario, we store the text to be printed as a variable called "message". This is then put in to the function, print.
#
# We can manipulate that piece of data now that we have stored it:

# %%
greeting = "Hello World."

message = greeting + " I am alive!"

print(message)
# Out:
# Hello World. I am alive!

# %% [markdown]
# ### Functions
#
# *Skippable!*
#
# print() is a built in function provided by default in Python.
#
# In programming, we often find ourselves doing repetitive tasks. Functions can store the steps of these tasks, so that they can be executed via a single line of code.
#
# As a result, we have the ability write our own functions:

# %%
def greeting(message):
    greeting = "Hello World."
    message = greeting + " " + message
    print(message)

message = "This is a function call."
greeting(message)
# Out:
# Hello World. This is a function call.

# %% [markdown]
# To declare a function, simply follow this format:
#
#     def function_name(variable1, variable2):
#
# Lines of code belonging to a function should be indented 1 tab character. For example:
#
#     def function_name(variable1, variable2):
#         this_is_apart_of_the_function = True
#
#     this_is_not_apart_of_the_function = False
#
# A function can even return a piece of data:

# %%
def make_greeting(message):
    greeting = "Hello World."
    message = greeting + " " + message
    return message

message = "This is a function call."
greeting = make_greeting(message)

print(greeting)
# Out:
# Hello World. This is a function call.

# %% [markdown]
# ### Data Types
#
# Variables can be of different data types.
#
# In the previous coding examples, I have shown you the String datatype:
#
#     String = "This is a string"
#
# And the Boolean data type:
#
#     is_it_raining = False
#     are_we_hacking = True
#
# There are many others to store different types of data:
#
#     Integer = 1234
#     3+3
#
#     Float = 12.34
#     2 * 12.34

# %% [markdown]
# ### Data structures
#
# Variables alone can only do so much. By placing variables within data structures, we can begin to preform more interesting tasks.
#
# For this Hackathon, we will only be looking at 1 data structure: Dictionaries.
#
# #### Dictionaries
#
# Dictionaries are known as "key-value" pairs. This means for each "key" there is a value associated with it.
#
# Here I have pre-initialized a dictionary with some key value pairs:
#
#     phone_dict = { "Police" : 911,
#                   "City of Toronto Archives": 4163970778,
#                   "Pizza-Pizza" : 4169671111 }
#
# This dictionary contains 3 key-value pairs. Each key is a String containing the name of a business. Each value is an Integer representing the phone number of the business.
#
# Note that, keys and values can be of any data type. We could have easily assigned the phone number to be the key and the name of the business to be the value.
#
# #### Common operations on dictionaries
#
# To add/edit a key-value pair inside a dictionary:
#
#     phone_dict = {}
#
#     # to add
#     phone_dict["Dominos"] = 4166407777
#
#     # now to edit an existing value
#     phone_dict["Dominos"] = 1234567890
#
# To access the value of a key:
#
#     print(phone_dict["Police"])
#
# And finally to check if a key is in a dictionary:
#
#     if "Pizza-Pizza" in phone_dict:
#         print('This is Pizza Pizza's number: ' + phone_dict["Pizza-Pizza"])
#     elif "Pizza-Pizza" not in phone_dict:
#         print('We don't have the number')
#
# Note that if you were to try to get the value for a key which doesn't exist in the dictionary, you would get an error message.

# %% [markdown]
# ## Lesson 2 - File I/O (Input & Output)
#
# As a member of the archive team, you are aware that there are thousands of individual files containing important information. Using Python you can access the text within these files and manipulate, sort and transform this data.
#
# For this section, we will only be looking at how to access data within a plain-text file (.txt). Matthew will show you how to access other file types (like PDF's) in a future section.

# %% [markdown]
# ### Opening and reading from a file
#
# You can open a file in Python using a single line:

# %%
with open("~$HF 2010-11 annual report final from MOHLTC.txt") as f:
    print('We opened it')
# Out:
# We opened it

# %% [markdown]
# In line 1, we open a file named "filename.txt" and stored a reference to this file in a variable called 'f'.
#
# To begin reading this file, we need to operate on this 'f'. So, we write:

# %%
with open("~$HF 2010-11 annual report final from MOHLTC.txt") as f:
    data = f.read()
    print(data)
# Out:
# Since I assumed this position five years ago, much has changed at the Foundation:  the Foundation moved offices from College Street to Jarvis Street; Ms. Sandy Hengeveld and Ms. Emmanuelle Fontaine joined the staff; the Foundation moved from a paper-based system to a web-based system for applications and reports; Drs. Keith Jarvie and Vivian Rakoff began and completed their terms as, respectively, Chair and Vice-Chair;  six new members have joined the Board of the Foundation – Drs. Mary Seeman, Gregory Brown, George Tolomizencko, Mr. Herman Gill, Ms. Clare Sullivan, and Ms. Jeanette Lewis; Drs. William Avison and Harriet MacMillan were appointed Chair and Vice-Chair of the Foundation, and the membership of both the Grants and Fellowships Committees has changed considerably  since 2005. The Foundation has, however, continued – as it has for nearly 45 years – to support excellent research to promote the mental health of Ontarians, to prevent mental illness, and to improve diagnosis, treatment, and rehabilitation.
#
# Perhaps the greatest change in my tenure as Executive Director has been the challenge of meeting the rising demand for mental health research funding in Ontario. In 2005, the Foundation received 65 fellowship/studentship applications and 60 grant applications; the Foundation was able to fund 33% of the fellowship/studentship applications and 25% of the grant applications.  In 2009, the number of fellowship/studentship applications had risen to 93 and the number of grant applications rose to 78; the Foundation was able to fund only 19% of the grant applications, but 34% of the fellowships/studentships.
#
# It is through the OMHF Board’s commitment to sustaining and enlarging the pool of mental health researchers in Ontario and its prudence in managing the funds provided through the generosity of the Government and taxpayers of Ontario that the Foundation has been able to continue to fulfill its mission.  The Board’s decision, for but one example, to allocate a greater portion of the available funds to support of students will ensure that mental health research in Ontario remains the most energetic in Canada. 	There are sure to be challenges ahead; I am also sure, however, that the Foundation with the counsel and support of the Board, the staff, the Ministry, and the volunteer scientists who serve on the Foundation’s peer review Committees will meet them and continue to deserve its reputation for excellence in mental health research.
#
# I am grateful for the support of many people over the past year. The Board of the Foundation, both those whose terms have expired and the current members, has offered wise counsel and encouragement. Ms. Fontaine and Ms. Hengeveld keep the Foundation running smoothly and are responsible for the web-based application system. Thanks also to the staff of the Ministry of Health and Long-Term Care – Vasanthi Srinivasan, Anne Bowlby, Brian Davidson, Danielle Laymen-Pleet, Christy Pentland, and Amy Herskowitz; their commitment to the mental health of Ontarians is evident in the work of the Foundation.
#
# The members of the Foundation’s peer review Committees – Grant and Fellowships – are the backbone of the Foundation’s mission. The Chairs of the Committees – Drs. Patricia Rosebush (McMaster) and Steffany Bennett (Ottawa) have completed their terms. Both have been energetic and wise in their leadership and have been of inestimable help to me. Dr. Michael Kawaja (Queen’s) will serve as Chair of the Grants Committee and Dr. John Sylvestre (Ottawa) as the Chair of Fellowships. As usual, there are arrivals and departures to acknowledge. Drs. Walter Rushlow and Tracy Vaillancourt have left the Grants Committee; we welcome Dr. Steven Laviolette to that Committee. Drs. Michael Mazurek and Ayal Schaffer have left the Fellowships Committee. My thanks to all of the panels’ members for their commitment to mental health in Ontario.
#
#
#
#
#
#
#
# Dr. Alexander Greer
#
# Executive Director
#
# July 2010

# %% [markdown]
# Here we store all text within the file in a String variable called data. When we print data, we print the contents of an entire file out the screen.
#
# And it only took 3 lines of code. Nice.

# %% [markdown]
# ### Breaking the data
#
# What if you wanted to access the words in the data? We can do this by using split(' ').
#
#     with open("~$HF 2010-11 annual report final from MOHLTC.txt") as f:
#         for line in f:
#             words = line.split(' ')
#             for word in words:
#                 print('One word within the file: ' + word)
#
# (*Hint*)
# Something interesting that you can do now, is that you can now count how many words there are in a file:
#
#     word_count = 0
#
#     with open("~$HF 2010-11 annual report final from MOHLTC.txt") as f:
#         for line in f:
#             words = line.split(' ')
#             for word in words:
#                 word_count = word_count + 1
#
#     print(word_count)

# %%
with open("~$HF 2010-11 annual report final from MOHLTC.txt") as f:
    for line in f:
        words = line.split(' ')
        print(words)

# %% [markdown]
# In most written languages around the world, words are seperated by whitespace. split(' ') stores each block of text in between spaces in to a List.
#
# We can also go through each element within a List by doing this:

# %%
with open("~$HF 2010-11 annual report final from MOHLTC.txt") as f:
    for line in f:
        words = line.split(' ')
        for word in words:
            print('One word within the file: ' + word)
# Out:
# One word within the file: Since
# One word within the file: I
# One word within the file: assumed
# One word within the file: this
# One word within the file: position
# One word within the file: five
# One word within the file: years
# One word within the file: ago,
# One word within the file: much
# One word within the file: has
# One word within the file: changed
# One word within the file: at
# One word within the file: the
# One word within the file: Foundation:
# One word within the file:
# One word within the file: the
# One word within the file: Foundation
# One word within the file: moved
# One word within the file: offices
# One word within the file: from
# One word within the file: College
# One word within the file: Street
# One word within the file: to
# One word within the file: Jarvis
# One word within the file: Street;
# One word within the file: Ms.
# One word within the file: Sandy
# One word within the file: Hengeveld
# One word within the file: and
# One word within the file: Ms.
# One word within the file: Emmanuelle
# One word within the file: Fontaine
# One word within the file: joined
# One word within the file: the
# One word within the file: staff;
# One word within the file: the
# One word within the file: Foundation
# One word within the file: moved
# One word within the file: from
# One word within the file: a
# One word within the file: paper-based
# One word within the file: system
# One word within the file: to
# One word within the file: a
# One word within the file: web-based
# One word within the file: system
# One word within the file: for
# One word within the file: applications
# One word within the file: and
# One word within the file: reports;
# One word within the file: Drs.
# One word within the file: Keith
# One word within the file: Jarvie
# One word within the file: and
# One word within the file: Vivian
# One word within the file: Rakoff
# One word within the file: began
# One word within the file: and
# One word within the file: completed
# One word within the file: their
# One word within the file: terms
# One word within the file: as,
# One word within the file: respectively,
# One word within the file: Chair
# One word within the file: and
# One word within the file: Vice-Chair;
# One word within the file:
# One word within the file: six
# One word within the file: new
# One word within the file: members
# One word within the file: have
# One word within the file: joined
# One word within the file: the
# One word within the file: Board
# One word within the file: of
# One word within the file: the
# One word within the file: Foundation
# One word within the file: –
# One word within the file: Drs.
# One word within the file: Mary
# One word within the file: Seeman,
# One word within the file: Gregory
# One word within the file: Brown,
# One word within the file: George
# One word within the file: Tolomizencko,
# One word within the file: Mr.
# One word within the file: Herman
# One word within the file: Gill,
# One word within the file: Ms.
# One word within the file: Clare
# One word within the file: Sullivan,
# One word within the file: and
# One word within the file: Ms.
# One word within the file: Jeanette
# One word within the file: Lewis;
# One word within the file: Drs.
# One word within the file: William
# One word within the file: Avison
# One word within the file: and
# One word within the file: Harriet
# One word within the file: MacMillan
# One word within the file: were
# One word within the file: appointed
# One word within the file: Chair
# One word within the file: and
# One word within the file: Vice-Chair
# One word within the file: of
# One word within the file: the
# One word within the file: Foundation,
# One word within the file: and
# One word within the file: the
# One word within the file: membership
# One word within the file: of
# One word within the file: both
# One word within the file: the
# One word within the file: Grants
# One word within the file: and
# One word within the file: Fellowships
# One word within the file: Committees
# One word within the file: has
# One word within the file: changed
# One word within the file: considerably
# One word within the file:
# One word within the file: since
# One word within the file: 2005.
# One word within the file: The
# One word within the file: Foundation
# One word within the file: has,
# One word within the file: however,
# One word within the file: continued
# One word within the file: –
# One word within the file: as
# One word within the file: it
# One word within the file: has
# One word within the file: for
# One word within the file: nearly
# One word within the file: 45
# One word within the file: years
# One word within the file: –
# One word within the file: to
# One word within the file: support
# One word within the file: excellent
# One word within the file: research
# One word within the file: to
# One word within the file: promote
# One word within the file: the
# One word within the file: mental
# One word within the file: health
# One word within the file: of
# One word within the file: Ontarians,
# One word within the file: to
# One word within the file: prevent
# One word within the file: mental
# One word within the file: illness,
# One word within the file: and
# One word within the file: to
# One word within the file: improve
# One word within the file: diagnosis,
# One word within the file: treatment,
# One word within the file: and
# One word within the file: rehabilitation.
# One word within the file:
# One word within the file:
#
# One word within the file:
#
# One word within the file: Perhaps
# One word within the file: the
# One word within the file: greatest
# One word within the file: change
# One word within the file: in
# One word within the file: my
# One word within the file: tenure
# One word within the file: as
# One word within the file: Executive
# One word within the file: Director
# One word within the file: has
# One word within the file: been
# One word within the file: the
# One word within the file: challenge
# One word within the file: of
# One word within the file: meeting
# One word within the file: the
# One word within the file: rising
# One word within the file: demand
# One word within the file: for
# One word within the file: mental
# One word within the file: health
# One word within the file: research
# One word within the file: funding
# One word within the file: in
# One word within the file: Ontario.
# One word within the file: In
# One word within the file: 2005,
# One word within the file: the
# One word within the file: Foundation
# One word within the file: received
# One word within the file: 65
# One word within the file: fellowship/studentship
# One word within the file: applications
# One word within the file: and
# One word within the file: 60
# One word within the file: grant
# One word within the file: applications;
# One word within the file: the
# One word within the file: Foundation
# One word within the file: was
# One word within the file: able
# One word within the file: to
# One word within the file: fund
# One word within the file: 33%
# One word within the file: of
# One word within the file: the
# One word within the file: fellowship/studentship
# One word within the file: applications
# One word within the file: and
# One word within the file: 25%
# One word within the file: of
# One word within the file: the
# One word within the file: grant
# One word within the file: applications.
# One word within the file:
# One word within the file: In
# One word within the file: 2009,
# One word within the file: the
# One word within the file: number
# One word within the file: of
# One word within the file: fellowship/studentship
# One word within the file: applications
# One word within the file: had
# One word within the file: risen
# One word within the file: to
# One word within the file: 93
# One word within the file: and
# One word within the file: the
# One word within the file: number
# One word within the file: of
# One word within the file: grant
# One word within the file: applications
# One word within the file: rose
# One word within the file: to
# One word within the file: 78;
# One word within the file: the
# One word within the file: Foundation
# One word within the file: was
# One word within the file: able
# One word within the file: to
# One word within the file: fund
# One word within the file: only
# One word within the file: 19%
# One word within the file: of
# One word within the file: the
# One word within the file: grant
# One word within the file: applications,
# One word within the file: but
# One word within the file: 34%
# One word within the file: of
# One word within the file: the
# One word within the file: fellowships/studentships.
# One word within the file:
# One word within the file:
#
# One word within the file:
#
# One word within the file: It
# One word within the file: is
# One word within the file: through
# One word within the file: the
# One word within the file: OMHF
# One word within the file: Board’s
# One word within the file: commitment
# One word within the file: to
# One word within the file: sustaining
# One word within the file: and
# One word within the file: enlarging
# One word within the file: the
# One word within the file: pool
# One word within the file: of
# One word within the file: mental
# One word within the file: health
# One word within the file: researchers
# One word within the file: in
# One word within the file: Ontario
# One word within the file: and
# One word within the file: its
# One word within the file: prudence
# One word within the file: in
# One word within the file: managing
# One word within the file: the
# One word within the file: funds
# One word within the file: provided
# One word within the file: through
# One word within the file: the
# One word within the file: generosity
# One word within the file: of
# One word within the file: the
# One word within the file: Government
# One word within the file: and
# One word within the file: taxpayers
# One word within the file: of
# One word within the file: Ontario
# One word within the file: that
# One word within the file: the
# One word within the file: Foundation
# One word within the file: has
# One word within the file: been
# One word within the file: able
# One word within the file: to
# One word within the file: continue
# One word within the file: to
# One word within the file: fulfill
# One word within the file: its
# One word within the file: mission.
# One word within the file:
# One word within the file: The
# One word within the file: Board’s
# One word within the file: decision,
# One word within the file: for
# One word within the file: but
# One word within the file: one
# One word within the file: example,
# One word within the file: to
# One word within the file: allocate
# One word within the file: a
# One word within the file: greater
# One word within the file: portion
# One word within the file: of
# One word within the file: the
# One word within the file: available
# One word within the file: funds
# One word within the file: to
# One word within the file: support
# One word within the file: of
# One word within the file: students
# One word within the file: will
# One word within the file: ensure
# One word within the file: that
# One word within the file: mental
# One word within the file: health
# One word within the file: research
# One word within the file: in
# One word within the file: Ontario
# One word within the file: remains
# One word within the file: the
# One word within the file: most
# One word within the file: energetic
# One word within the file: in
# One word within the file: Canada.
# One word within the file: 	There
# One word within the file: are
# One word within the file: sure
# One word within the file: to
# One word within the file: be
# One word within the file: challenges
# One word within the file: ahead;
# One word within the file: I
# One word within the file: am
# One word within the file: also
# One word within the file: sure,
# One word within the file: however,
# One word within the file: that
# One word within the file: the
# One word within the file: Foundation
# One word within the file: with
# One word within the file: the
# One word within the file: counsel
# One word within the file: and
# One word within the file: support
# One word within the file: of
# One word within the file: the
# One word within the file: Board,
# One word within the file: the
# One word within the file: staff,
# One word within the file: the
# One word within the file: Ministry,
# One word within the file: and
# One word within the file: the
# One word within the file: volunteer
# One word within the file: scientists
# One word within the file: who
# One word within the file: serve
# One word within the file: on
# One word within the file: the
# One word within the file: Foundation’s
# One word within the file: peer
# One word within the file: review
# One word within the file: Committees
# One word within the file: will
# One word within the file: meet
# One word within the file: them
# One word within the file: and
# One word within the file: continue
# One word within the file: to
# One word within the file: deserve
# One word within the file: its
# One word within the file: reputation
# One word within the file: for
# One word within the file: excellence
# One word within the file: in
# One word within the file: mental
# One word within the file: health
# One word within the file: research.
#
# One word within the file:
#
# One word within the file: I
# One word within the file: am
# One word within the file: grateful
# One word within the file: for
# One word within the file: the
# One word within the file: support
# One word within the file: of
# One word within the file: many
# One word within the file: people
# One word within the file: over
# One word within the file: the
# One word within the file: past
# One word within the file: year.
# One word within the file: The
# One word within the file: Board
# One word within the file: of
# One word within the file: the
# One word within the file: Foundation,
# One word within the file: both
# One word within the file: those
# One word within the file: whose
# One word within the file: terms
# One word within the file: have
# One word within the file: expired
# One word within the file: and
# One word within the file: the
# One word within the file: current
# One word within the file: members,
# One word within the file: has
# One word within the file: offered
# One word within the file: wise
# One word within the file: counsel
# One word within the file: and
# One word within the file: encouragement.
# One word within the file: Ms.
# One word within the file: Fontaine
# One word within the file: and
# One word within the file: Ms.
# One word within the file: Hengeveld
# One word within the file: keep
# One word within the file: the
# One word within the file: Foundation
# One word within the file: running
# One word within the file: smoothly
# One word within the file: and
# One word within the file: are
# One word within the file: responsible
# One word within the file: for
# One word within the file: the
# One word within the file: web-based
# One word within the file: application
# One word within the file: system.
# One word within the file: Thanks
# One word within the file: also
# One word within the file: to
# One word within the file: the
# One word within the file: staff
# One word within the file: of
# One word within the file: the
# One word within the file: Ministry
# One word within the file: of
# One word within the file: Health
# One word within the file: and
# One word within the file: Long-Term
# One word within the file: Care
# One word within the file: –
# One word within the file: Vasanthi
# One word within the file: Srinivasan,
# One word within the file: Anne
# One word within the file: Bowlby,
# One word within the file: Brian
# One word within the file: Davidson,
# One word within the file: Danielle
# One word within the file: Laymen-Pleet,
# One word within the file: Christy
# One word within the file: Pentland,
# One word within the file: and
# One word within the file: Amy
# One word within the file: Herskowitz;
# One word within the file: their
# One word within the file: commitment
# One word within the file: to
# One word within the file: the
# One word within the file: mental
# One word within the file: health
# One word within the file: of
# One word within the file: Ontarians
# One word within the file: is
# One word within the file: evident
# One word within the file: in
# One word within the file: the
# One word within the file: work
# One word within the file: of
# One word within the file: the
# One word within the file: Foundation.
#
# One word within the file:
#
# One word within the file: The
# One word within the file: members
# One word within the file: of
# One word within the file: the
# One word within the file: Foundation’s
# One word within the file: peer
# One word within the file: review
# One word within the file: Committees
# One word within the file: –
# One word within the file: Grant
# One word within the file: and
# One word within the file: Fellowships
# One word within the file: –
# One word within the file: are
# One word within the file: the
# One word within the file: backbone
# One word within the file: of
# One word within the file: the
# One word within the file: Foundation’s
# One word within the file: mission.
# One word within the file: The
# One word within the file: Chairs
# One word within the file: of
# One word within the file: the
# One word within the file: Committees
# One word within the file: –
# One word within the file: Drs.
# One word within the file: Patricia
# One word within the file: Rosebush
# One word within the file: (McMaster)
# One word within the file: and
# One word within the file: Steffany
# One word within the file: Bennett
# One word within the file: (Ottawa)
# One word within the file: have
# One word within the file: completed
# One word within the file: their
# One word within the file: terms.
# One word within the file: Both
# One word within the file: have
# One word within the file: been
# One word within the file: energetic
# One word within the file: and
# One word within the file: wise
# One word within the file: in
# One word within the file: their
# One word within the file: leadership
# One word within the file: and
# One word within the file: have
# One word within the file: been
# One word within the file: of
# One word within the file: inestimable
# One word within the file: help
# One word within the file: to
# One word within the file: me.
# One word within the file: Dr.
# One word within the file: Michael
# One word within the file: Kawaja
# One word within the file: (Queen’s)
# One word within the file: will
# One word within the file: serve
# One word within the file: as
# One word within the file: Chair
# One word within the file: of
# One word within the file: the
# One word within the file: Grants
# One word within the file: Committee
# One word within the file: and
# One word within the file: Dr.
# One word within the file: John
# One word within the file: Sylvestre
# One word within the file: (Ottawa)
# One word within the file: as
# One word within the file: the
# One word within the file: Chair
# One word within the file: of
# One word within the file: Fellowships.
# One word within the file: As
# One word within the file: usual,
# One word within the file: there
# One word within the file: are
# One word within the file: arrivals
# One word within the file: and
# One word within the file: departures
# One word within the file: to
# One word within the file: acknowledge.
# One word within the file: Drs.
# One word within the file: Walter
# One word within the file: Rushlow
# One word within the file: and
# One word within the file: Tracy
# One word within the file: Vaillancourt
# One word within the file: have
# One word within the file: left
# One word within the file: the
# One word within the file: Grants
# One word within the file: Committee;
# One word within the file: we
# One word within the file: welcome
# One word within the file: Dr.
# One word within the file: Steven
# One word within the file: Laviolette
# One word within the file: to
# One word within the file: that
# One word within the file: Committee.
# One word within the file: Drs.
# One word within the file: Michael
# One word within the file: Mazurek
# One word within the file: and
# One word within the file: Ayal
# One word within the file: Schaffer
# One word within the file: have
# One word within the file: left
# One word within the file: the
# One word within the file: Fellowships
# One word within the file: Committee.
# One word within the file: My
# One word within the file: thanks
# One word within the file: to
# One word within the file: all
# One word within the file: of
# One word within the file: the
# One word within the file: panels’
# One word within the file: members
# One word within the file: for
# One word within the file: their
# One word within the file: commitment
# One word within the file: to
# One word within the file: mental
# One word within the file: health
# One word within the file: in
# One word within the file: Ontario.
#
# One word within the file:
#
# One word within the file:
#
# One word within the file:
#
# One word within the file:
#
# One word within the file:
#
# One word within the file:
#
# One word within the file:
#
# One word within the file: Dr.
# One word within the file: Alexander
# One word within the file: Greer
#
# One word within the file:
#
# One word within the file: Executive
# One word within the file: Director
#
# One word within the file:
#
# One word within the file: July
# One word within the file: 2010

# %% [markdown]
# (*Hint*)
# Something interesting that you can do now, is that you can now count how many words there are in a file:

# %%
word_count = 0
    
with open("~$HF 2010-11 annual report final from MOHLTC.txt") as f:
    for line in f:
        words = line.split(' ')
        for word in words:
            word_count = word_count + 1
    
print(word_count)
# Out:
# 643

# %% [markdown]
# ### Writing to files
#
# *Skippable!*
#
# It is possible to write lines of text to a file. We use similar code as reading:
#
#     with open("filename.txt", "w") as f:
#        f.write("I love programming in Python.")
#
# Note a few differences:
#     1. We open "filename.txt" in 'w' mode - write mode.
#     2. We still store a reference to this file in a variable called 'f'
#     3. But we can now use the 'write' operation. If you were to open a file in read mode and run this line of code, your script would crash
#
# Writing to files is important, but is not as relevant to this Hackathon.

# %% [markdown]
# ### Programming challenge #1
#
# Section requirements:
#     1. Data structures
#     2. Opening and reading a file
#     3. Breaking down each line
#
# Now that you can read the contents of a file and store data inside a data structure, can you do both by storing the count of each word in to a Dictionary?
#
# (*Hint*) Your program will first need to have a completely empty dictionary. This can be initialized by using:
#
#     word_count_dict = {}

# %% [markdown]
# ## Lesson 3 - Parallel Programming
#
# In the world of big data analytics, it not unusual that a computational job takes a single computer several days to complete. A common way to lower the time a program's runs for is to distribute certain portions of the job across many computers running simultaneously.
#
# The field of using simultaneous computional processes is known as parallel computing.

# %% [markdown]
# ### Data Parallelism
#
# ![Image of Data Parallelism](https://computing.llnl.gov/tutorials/parallel_comp/images/domain_decomp.gif)
#
# Data parallelism is the most well known method to achieve parallel computing. In this method, the input data set is divided equally and sent to multiple processes.
#
# Here is an analogy. Lets say that I want to make an entire bag of flour in to pizza dough. If I were to make a set amount alone, it would take me a while, lets say 4 hours. If 3 of my buddies joined in and we were making this dough all at the same time, it would take me 4 / 4 = 1 hour. Each buddy would take 1/4th of the flour to make the dough.
#
# Data paralleism works in a similar way. Each "worker" process preforms the exactly the same task, but is given a different set of inputs to work on.

# %%
#### Data parallelism coding example

import multiprocessing as mp
import string

output = mp.Queue()

def load_data(file):
    with open(file) as f:
        data = f.read()
        for f in string.punctuation:
            data = data.strip(f)
        return data.split(' ')

def count(output, data, begin, end):
    unique_words = {}
    for word in data[int(begin):int(end)]:
        if word in unique_words:
            unique_words[word] = unique_words[word] + 1
        else:
            unique_words[word] = 1
    output.put(unique_words)

if __name__ == "__main__":
    data = load_data("~$HF 2010-11 annual report final from MOHLTC.txt")
    number_of_words_in_data = len(data)
    set_size = number_of_words_in_data / 4
        
    processes = []
    
    # Specify which input data each "worker" process gets
    for x in range(4):
        begin = set_size * x
        end = min(set_size * (x+1), number_of_words_in_data)
        p = mp.Process(target=count, args=(output, data, begin, end))
        
        processes.append(p)
        
        print('Adding process %i, which runs on the word # %i - %i.' % (x, begin, end))
        
    # Run processes
    for p in processes:
        p.start()

    # Exit the completed processes
    for p in processes:
        p.join()

    # Get process results
    results = [output.get() for p in processes]
    
    # Print the results to the screen
    for process_id, result in enumerate(results):
        print("Process %i found the following word counts in its section:" % process_id)
        print(str(result))
# Out:
# Adding process 0, which runs on the word # 0 - 155.
# Adding process 1, which runs on the word # 155 - 311.
# Adding process 2, which runs on the word # 311 - 467.
# Adding process 3, which runs on the word # 467 - 623.
# 4
# Process 0 found the following word counts in its section:
# {'Since': 1, 'I': 1, 'assumed': 1, 'this': 1, 'position': 1, 'five': 1, 'years': 2, 'ago,': 1, 'much': 1, 'has': 3, 'changed': 2, 'at': 1, 'the': 10, 'Foundation:': 1, '': 3, 'Foundation': 4, 'moved': 2, 'offices': 1, 'from': 2, 'College': 1, 'Street': 1, 'to': 5, 'Jarvis': 1, 'Street;': 1, 'Ms.': 4, 'Sandy': 1, 'Hengeveld': 1, 'and': 11, 'Emmanuelle': 1, 'Fontaine': 1, 'joined': 2, 'staff;': 1, 'a': 2, 'paper-based': 1, 'system': 2, 'web-based': 1, 'for': 2, 'applications': 1, 'reports;': 1, 'Drs.': 3, 'Keith': 1, 'Jarvie': 1, 'Vivian': 1, 'Rakoff': 1, 'began': 1, 'completed': 1, 'their': 1, 'terms': 1, 'as,': 1, 'respectively,': 1, 'Chair': 2, 'Vice-Chair;': 1, 'six': 1, 'new': 1, 'members': 1, 'have': 1, 'Board': 1, 'of': 4, '–': 3, 'Mary': 1, 'Seeman,': 1, 'Gregory': 1, 'Brown,': 1, 'George': 1, 'Tolomizencko,': 1, 'Mr.': 1, 'Herman': 1, 'Gill,': 1, 'Clare': 1, 'Sullivan,': 1, 'Jeanette': 1, 'Lewis;': 1, 'William': 1, 'Avison': 1, 'Harriet': 1, 'MacMillan': 1, 'were': 1, 'appointed': 1, 'Vice-Chair': 1, 'Foundation,': 1, 'membership': 1, 'both': 1, 'Grants': 1, 'Fellowships': 1, 'Committees': 1, 'considerably': 1, 'since': 1, '2005.': 1, 'The': 1, 'has,': 1, 'however,': 1, 'continued': 1, 'as': 1, 'it': 1, 'nearly': 1, '45': 1, 'support': 1, 'excellent': 1, 'research': 1, 'promote': 1, 'mental': 2, 'health': 1, 'Ontarians,': 1, 'prevent': 1, 'illness,': 1}
# Process 1 found the following word counts in its section:
# {'to': 8, 'improve': 1, 'diagnosis,': 1, 'treatment,': 1, 'and': 7, 'rehabilitation.': 1, '': 4, '\n\nPerhaps': 1, 'the': 18, 'greatest': 1, 'change': 1, 'in': 4, 'my': 1, 'tenure': 1, 'as': 1, 'Executive': 1, 'Director': 1, 'has': 2, 'been': 2, 'challenge': 1, 'of': 10, 'meeting': 1, 'rising': 1, 'demand': 1, 'for': 2, 'mental': 2, 'health': 2, 'research': 1, 'funding': 1, 'Ontario.': 1, 'In': 2, '2005,': 1, 'Foundation': 4, 'received': 1, '65': 1, 'fellowship/studentship': 3, 'applications': 4, '60': 1, 'grant': 4, 'applications;': 1, 'was': 2, 'able': 3, 'fund': 2, '33%': 1, '25%': 1, 'applications.': 1, '2009,': 1, 'number': 2, 'had': 1, 'risen': 1, '93': 1, 'rose': 1, '78;': 1, 'only': 1, '19%': 1, 'applications,': 1, 'but': 2, '34%': 1, 'fellowships/studentships.': 1, '\n\nIt': 1, 'is': 1, 'through': 2, 'OMHF': 1, 'Board’s': 2, 'commitment': 1, 'sustaining': 1, 'enlarging': 1, 'pool': 1, 'researchers': 1, 'Ontario': 2, 'its': 2, 'prudence': 1, 'managing': 1, 'funds': 1, 'provided': 1, 'generosity': 1, 'Government': 1, 'taxpayers': 1, 'that': 1, 'continue': 1, 'fulfill': 1, 'mission.': 1, 'The': 1, 'decision,': 1}
# Process 2 found the following word counts in its section:
# {'one': 1, 'example,': 1, 'to': 5, 'allocate': 1, 'a': 1, 'greater': 1, 'portion': 1, 'of': 7, 'the': 17, 'available': 1, 'funds': 1, 'support': 3, 'students': 1, 'will': 2, 'ensure': 1, 'that': 2, 'mental': 2, 'health': 2, 'research': 1, 'in': 3, 'Ontario': 1, 'remains': 1, 'most': 1, 'energetic': 1, 'Canada.': 1, '\tThere': 1, 'are': 2, 'sure': 1, 'be': 1, 'challenges': 1, 'ahead;': 1, 'I': 1, 'am': 2, 'also': 2, 'sure,': 1, 'however,': 1, 'Foundation': 2, 'with': 1, 'counsel': 2, 'and': 8, 'Board,': 1, 'staff,': 1, 'Ministry,': 1, 'volunteer': 1, 'scientists': 1, 'who': 1, 'serve': 1, 'on': 1, 'Foundation’s': 1, 'peer': 1, 'review': 1, 'Committees': 1, 'meet': 1, 'them': 1, 'continue': 1, 'deserve': 1, 'its': 1, 'reputation': 1, 'for': 3, 'excellence': 1, 'research.\n\nI': 1, 'grateful': 1, 'many': 1, 'people': 1, 'over': 1, 'past': 1, 'year.': 1, 'The': 1, 'Board': 1, 'Foundation,': 1, 'both': 1, 'those': 1, 'whose': 1, 'terms': 1, 'have': 1, 'expired': 1, 'current': 1, 'members,': 1, 'has': 1, 'offered': 1, 'wise': 1, 'encouragement.': 1, 'Ms.': 2, 'Fontaine': 1, 'Hengeveld': 1, 'keep': 1, 'running': 1, 'smoothly': 1, 'responsible': 1, 'web-based': 1, 'application': 1, 'system.': 1, 'Thanks': 1, 'staff': 1, 'Ministry': 1, 'Health': 1, 'Long-Term': 1, 'Care': 1, '–': 1, 'Vasanthi': 1, 'Srinivasan,': 1, 'Anne': 1, 'Bowlby,': 1, 'Brian': 1, 'Davidson,': 1, 'Danielle': 1, 'Laymen-Pleet,': 1}
# Process 3 found the following word counts in its section:
# {'Christy': 1, 'Pentland,': 1, 'and': 9, 'Amy': 1, 'Herskowitz;': 1, 'their': 4, 'commitment': 2, 'to': 6, 'the': 12, 'mental': 2, 'health': 2, 'of': 9, 'Ontarians': 1, 'is': 1, 'evident': 1, 'in': 3, 'work': 1, 'Foundation.\n\nThe': 1, 'members': 2, 'Foundation’s': 2, 'peer': 1, 'review': 1, 'Committees': 2, '–': 3, 'Grant': 1, 'Fellowships': 2, 'are': 2, 'backbone': 1, 'mission.': 1, 'The': 1, 'Chairs': 1, 'Drs.': 3, 'Patricia': 1, 'Rosebush': 1, '(McMaster)': 1, 'Steffany': 1, 'Bennett': 1, '(Ottawa)': 2, 'have': 5, 'completed': 1, 'terms.': 1, 'Both': 1, 'been': 2, 'energetic': 1, 'wise': 1, 'leadership': 1, 'inestimable': 1, 'help': 1, 'me.': 1, 'Dr.': 3, 'Michael': 2, 'Kawaja': 1, '(Queen’s)': 1, 'will': 1, 'serve': 1, 'as': 2, 'Chair': 2, 'Grants': 2, 'Committee': 1, 'John': 1, 'Sylvestre': 1, 'Fellowships.': 1, 'As': 1, 'usual,': 1, 'there': 1, 'arrivals': 1, 'departures': 1, 'acknowledge.': 1, 'Walter': 1, 'Rushlow': 1, 'Tracy': 1, 'Vaillancourt': 1, 'left': 2, 'Committee;': 1, 'we': 1, 'welcome': 1, 'Steven': 1, 'Laviolette': 1, 'that': 1, 'Committee.': 2, 'Mazurek': 1, 'Ayal': 1, 'Schaffer': 1, 'My': 1, 'thanks': 1, 'all': 1, 'panels’': 1, 'for': 1, 'Ontario.\n\n\n\n\n\n\n\nDr.': 1, 'Alexander': 1, 'Greer\n\nExecutive': 1, 'Director\n\nJuly': 1, '2010': 1}

# %% [markdown]
# ### A note
#
# In reality, you will most likely be using tools which already implement parallel processing. In Shaikh's upcoming section, he will touch a little on Hadoop and how it can run on multiple computers. oooo.

# %% [markdown]
# ### Programming challenge #2
#
# This is one for experienced programmers.
#
# In the above coding example, I showed you how to print a list of unique words corresponding to sections of the a body of text. Can you modify the program to show word counts across the whole document? You will need to combine the results of each process and store them in a central dictionary.
#
# *Hint*: To iterate across all key-value pairs within a dictionary:
#
#     for key, value in dictionary.values():
#         print(key, value)

# %% [markdown]
# ## What's next?
#
# Congratulations! You have finished the first section of this Hackathon. You did it. You are the programmer.
#
# ![Image of Hacker](https://ak1.picdn.net/shutterstock/videos/3365171/thumb/1.jpg)
#
# By the end of this section you will have touched upon how to read and store data in addition to having done a basic word count analysis. You will have touched on the topic of parallel computing as well.
#
# In future sections, you will learn how to read data in from other file extensions (.pdf, .doc, .xls etc.) and advanced analysis using machine learning models.
